# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;

df = pd.read_csv(r"dataset\Raw_carbon_emission_dataset_with_Industry.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18250 entries, 0 to 18249
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Company_ID                           18250 non-null  object
#  1   Date                                 18250 non-null  object
#  2   Sector                               18250 non-null  object
#  3   Total_Energy_Consumption_kWh         18250 non-null  float64
#  4   Renewable_Energy_Consumption_kWh     18250 non-null  float64
#  5   NonRenewable_Energy_Consumption_kWh  18250 non-null  float64
#  6   Production_Output_Units              18250 non-null  float64
#  7   Supply_Chain_Transport_km            18250 non-null  float64
#  8   Supply_Chain_Transport_Mode          18250 non-null  object
#  9   Raw_Material_Usage_kg                18250 non-null  float64
#  10  Carbon_Emission_tCO2e_TARGET         18250 non-null  float64
# ...

# %%
df.head()
# Out:
#   Company_ID        Date         Sector  Total_Energy_Consumption_kWh  \
# 0       C001  2024-01-01  Manufacturing                      53751.61
# 1       C001  2024-01-02  Manufacturing                     170872.89
# 2       C001  2024-01-03  Manufacturing                     142777.96
# 3       C001  2024-01-04  Manufacturing                     152532.15
# 4       C001  2024-01-05  Manufacturing                      81647.43
#
#    Renewable_Energy_Consumption_kWh  NonRenewable_Energy_Consumption_kWh  \
# 0                          12766.80                             40984.81
# 1                          76733.84                             94139.05
# 2                          75794.17                             66983.79
# 3                          20698.80                            131833.35
# 4                          46657.82                             34989.61
#
#    Production_Output_Units  Supply_Chain_Transport_km  \
# ...

# %%
df.tail()
# Out:
#       Company_ID        Date     Sector  Total_Energy_Consumption_kWh  \
# 18245       C050  2024-12-26  Transport                      69673.43
# 18246       C050  2024-12-27  Transport                     147667.28
# 18247       C050  2024-12-28  Transport                      59522.00
# 18248       C050  2024-12-29  Transport                      97234.51
# 18249       C050  2024-12-30  Transport                     163312.60
#
#        Renewable_Energy_Consumption_kWh  NonRenewable_Energy_Consumption_kWh  \
# 18245                          29071.24                             40602.19
# 18246                          24376.01                            123291.27
# 18247                          34483.55                             25038.45
# 18248                          12443.10                             84791.41
# 18249                          84313.71                             78998.89
#
#        Production_Output_Units  Supply_Chain_Transport_km  \
# ...

# %%
df['Date'].head
# Out:
# <bound method NDFrame.head of 0        2024-01-01
# 1        2024-01-02
# 2        2024-01-03
# 3        2024-01-04
# 4        2024-01-05
#             ...
# 18245    2024-12-26
# 18246    2024-12-27
# 18247    2024-12-28
# 18248    2024-12-29
# 18249    2024-12-30
# Name: Date, Length: 18250, dtype: object>

# %%
df.isnull().sum()       #No Missing Value
# Out:
# Company_ID                             0
# Date                                   0
# Sector                                 0
# Total_Energy_Consumption_kWh           0
# Renewable_Energy_Consumption_kWh       0
# NonRenewable_Energy_Consumption_kWh    0
# Production_Output_Units                0
# Supply_Chain_Transport_km              0
# Supply_Chain_Transport_Mode            0
# Raw_Material_Usage_kg                  0
# Carbon_Emission_tCO2e_TARGET           0
# Energy_Cost_USD                        0
# Carbon_Tax_USD                         0
# Process_Efficiency_Percent             0
# Employment_Count                       0
# Public_Acceptance_Index                0
# Carbon_Reduction_Strategy              0
# Strategy_Implementation_Cost_USD       0
# Expected_Carbon_Reduction_Percent      0
# Expected_Renewable_Share_Percent       0
# Social_Impact_Score                    0
# Industry_Sectors                       0
# dtype: int64

# %%
df.duplicated().sum()    #Zero duplicate
# Out:
# 0

# %%
df['Date'] =pd.to_datetime(df['Date'])     #Conversion of Date
df['Date'].dtype

print("Start:",df['Date'].min())
print("End:",df['Date'].max())
# Out:
# Start: 2024-01-01 00:00:00
# End: 2024-12-30 00:00:00

# %%
# Checking Categorial Columns
categorial_cols = df.select_dtypes(include='object').columns

for columns in categorial_cols:
    print("\n",columns)
    print(df[columns].nunique())
    print(df[columns].unique()[:20])
# Out:
#  Company_ID
# 50
# ['C001' 'C002' 'C003' 'C004' 'C005' 'C006' 'C007' 'C008' 'C009' 'C010'
#  'C011' 'C012' 'C013' 'C014' 'C015' 'C016' 'C017' 'C018' 'C019' 'C020']
#
#  Sector
# 5
# ['Manufacturing' 'Agriculture' 'Energy' 'Transport' 'IT']
#
#  Supply_Chain_Transport_Mode
# 4
# ['Truck' 'Air' 'Ship' 'Rail']
#
#  Carbon_Reduction_Strategy
# 4
# ['Process Reengineering' 'Efficiency Upgrade' 'Carbon Tax Compliance'
#  'Renewable Adoption']
#
#  Industry_Sectors
# 4
# ['Steel Manufacturing' 'Cement Production' 'Automotive Industry'
#  'Logistics']

# %%
# Numerical Columns                                          # No Negative Value
numeric_cols = df.select_dtypes(include='number').columns
df[numeric_cols].describe().T                                # T - rotate the table means column in row
# Out:
#                                        count           mean            std  \
# Total_Energy_Consumption_kWh         18250.0  124776.987158   43106.624251
# Renewable_Energy_Consumption_kWh     18250.0   43759.097184   24291.666951
# NonRenewable_Energy_Consumption_kWh  18250.0   81017.889975   33957.852247
# Production_Output_Units              18250.0    5538.963915    2597.576117
# Supply_Chain_Transport_km            18250.0    2734.813587    1300.146027
# Raw_Material_Usage_kg                18250.0   44869.415215   20110.509566
# Carbon_Emission_tCO2e_TARGET         18250.0      32.365099      14.482041
# Energy_Cost_USD                      18250.0   10600.982042    4532.900551
# Carbon_Tax_USD                       18250.0    1129.541275     590.407029
# Process_Efficiency_Percent           18250.0      77.623844      10.112534
# Employment_Count                     18250.0    2734.349041    1298.648265
# ...

# %%
#Outlier 
Q1 = df["Carbon_Emission_tCO2e_TARGET"].quantile(0.25)
Q2 = df["Carbon_Emission_tCO2e_TARGET"].quartile(0.75)
